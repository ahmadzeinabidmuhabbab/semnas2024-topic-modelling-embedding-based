# %%
# !pip install -r requirements.txt
# Out:
# /usr/local/lib/python3.6/pty.py:84: ResourceWarning: Unclosed socket <zmq.Socket(zmq.PUSH) at 0x7bab4c2ff0f0>
#   pid, fd = os.forkpty()
# Defaulting to user installation because normal site-packages is not writeable
# Collecting octis
#   Using cached octis-1.13.1-py2.py3-none-any.whl (130 kB)
# Collecting umap-learn
#   Using cached umap_learn-0.5.6-py3-none-any.whl (85 kB)
# Collecting hdbscan
#   Using cached hdbscan-0.8.37-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
# Collecting simcse==0.4
#   Using cached simcse-0.4.tar.gz (18 kB)
#   Preparing metadata (setup.py) ... done
# Collecting plotly
#   Using cached plotly-5.22.0-py3-none-any.whl (16.4 MB)
# Collecting flair
#   Using cached flair-0.13.1-py3-none-any.whl (388 kB)
# Collecting numpy<1.20,>=1.19.5
#   Using cached numpy-1.19.5.zip (7.3 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: scikit-learn in /home/abid/.local/lib/python3.10/site-packages (from simcse==0.4->-r requirements.txt (line 4)) (1.3.2)
# Collecting scipy<1.6,>=1.5.4
#   Using cached scipy-1.5.4.tar.gz (25.2 MB)
#   Installing build dependencies ... error
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> [3482 lines of output]
#       Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX"' don't match your environment
#       Ignoring numpy: markers 'python_version == "3.7" and platform_system != "AIX"' don't match your environment
#       Ignoring numpy: markers 'python_version == "3.6" and platform_system == "AIX"' don't match your environment
#       Ignoring numpy: markers 'python_version == "3.7" and platform_system == "AIX"' don't match your environment
#       Ignoring numpy: markers 'python_version >= "3.8" and platform_system == "AIX"' don't match your environment
#       Collecting wheel
#         Using cached wheel-0.43.0-py3-none-any.whl (65 kB)
#       Collecting setuptools
#         Using cached setuptools-70.3.0-py3-none-any.whl (931 kB)
#       Collecting Cython>=0.29.18
#         Using cached Cython-3.0.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#       Collecting numpy==1.17.3
#         Using cached numpy-1.17.3.zip (6.4 MB)
#         Preparing metadata (setup.py): started
#         Preparing metadata (setup.py): finished with status 'done'
#       Collecting pybind11>=2.4.3
#         Using cached pybind11-2.13.1-py3-none-any.whl (238 kB)
#       Building wheels for collected packages: numpy
#         Building wheel for numpy (setup.py): started
#         Building wheel for numpy (setup.py): finished with status 'error'
#         error: subprocess-exited-with-error
#
#         × python setup.py bdist_wheel did not run successfully.
#         │ exit code: 1
#         ╰─> [2924 lines of output]
#             Running from numpy source directory.
#             blas_opt_info:
#             blas_mkl_info:
#             customize UnixCCompiler
#               libraries mkl_rt not found in ['/usr/local/lib', '/usr/lib64', '/usr/lib', '/usr/lib/x86_64-linux-gnu']
#               NOT AVAILABLE
#
#             blis_info:
#             customize UnixCCompiler
#               libraries blis not found in ['/usr/local/lib', '/usr/lib64', '/usr/lib', '/usr/lib/x86_64-linux-gnu']
#               NOT AVAILABLE
#
#             openblas_info:
#             customize UnixCCompiler
#             customize UnixCCompiler
#             customize UnixCCompiler
#               FOUND:
#                 libraries = ['openblas', 'openblas']
#                 library_dirs = ['/usr/lib/x86_64-linux-gnu']
#                 language = c
#                 define_macros = [('HAVE_CBLAS', None)]
#
#               FOUND:
#                 libraries = ['openblas', 'openblas']
#                 library_dirs = ['/usr/lib/x86_64-linux-gnu']
#                 language = c
#                 define_macros = [('HAVE_CBLAS', None)]
#
#             /bin/sh: 1: svnversion: Permission denied
#             non-existing path in 'numpy/distutils': 'site.cfg'
#             lapack_opt_info:
#             lapack_mkl_info:
#             customize UnixCCompiler
#               libraries mkl_rt not found in ['/usr/local/lib', '/usr/lib64', '/usr/lib', '/usr/lib/x86_64-linux-gnu']
#               NOT AVAILABLE
#
#             openblas_lapack_info:
#             customize UnixCCompiler
#             customize UnixCCompiler
#             customize UnixCCompiler
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             creating /tmp/tmp3j2bklo_/tmp
#             creating /tmp/tmp3j2bklo_/tmp/tmp3j2bklo_
#             compile options: '-c'
#             x86_64-linux-gnu-gcc: /tmp/tmp3j2bklo_/source.c
#             x86_64-linux-gnu-gcc /tmp/tmp3j2bklo_/tmp/tmp3j2bklo_/source.o -lopenblas -o /tmp/tmp3j2bklo_/a.out
#             customize UnixCCompiler
#               FOUND:
#                 libraries = ['openblas', 'openblas']
#                 library_dirs = ['/usr/lib/x86_64-linux-gnu']
#                 language = c
#                 define_macros = [('HAVE_CBLAS', None)]
#
#               FOUND:
#                 libraries = ['openblas', 'openblas']
#                 library_dirs = ['/usr/lib/x86_64-linux-gnu']
#                 language = c
#                 define_macros = [('HAVE_CBLAS', None)]
#
#             /usr/lib/python3.10/distutils/dist.py:274: UserWarning: Unknown distribution option: 'define_macros'
#               warnings.warn(msg)
#             running bdist_wheel
#             running build
#             running config_cc
#             unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#             running config_fc
#             unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#             running build_src
#             build_src
#             building py_modules sources
#             creating build
#             creating build/src.linux-x86_64-3.1
#             creating build/src.linux-x86_64-3.1/numpy
#             creating build/src.linux-x86_64-3.1/numpy/distutils
#             building library "npymath" sources
#             get_default_fcompiler: matching types: '['gnu95', 'intel', 'lahey', 'pg', 'absoft', 'nag', 'vast', 'compaq', 'intele', 'intelem', 'gnu', 'g95', 'pathf95', 'nagfor']'
#             customize Gnu95FCompiler
#             Could not locate executable gfortran
#             Could not locate executable f95
#             customize IntelFCompiler
#             Could not locate executable ifort
#             Could not locate executable ifc
#             customize LaheyFCompiler
#             Could not locate executable lf95
#             customize PGroupFCompiler
#             Could not locate executable pgfortran
#             customize AbsoftFCompiler
#             Could not locate executable f90
#             Could not locate executable f77
#             customize NAGFCompiler
#             customize VastFCompiler
#             customize CompaqFCompiler
#             Could not locate executable fort
#             customize IntelItaniumFCompiler
#             Could not locate executable efort
#             Could not locate executable efc
#             customize IntelEM64TFCompiler
#             customize GnuFCompiler
#             Could not locate executable g77
#             customize G95FCompiler
#             Could not locate executable g95
#             customize PathScaleFCompiler
#             Could not locate executable pathf95
#             customize NAGFORCompiler
#             Could not locate executable nagfor
#             don't know how to compile Fortran code on platform 'posix'
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             x86_64-linux-gnu-gcc _configtest.o -o _configtest
#             success!
#             removing: _configtest.c _configtest.o _configtest.o.d _configtest
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c:1:5: warning: conflicting types for built-in function ‘exp’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#                 1 | int exp (void);
#                   |     ^~~
#             _configtest.c:1:1: note: ‘exp’ is declared in header ‘<math.h>’
#               +++ |+#include <math.h>
#                 1 | int exp (void);
#             x86_64-linux-gnu-gcc _configtest.o -o _configtest
#             /usr/bin/ld: _configtest.o: in function `main':
#             /tmp/pip-install-m3epvlos/numpy_e0b647e5fe12423cb444c53cf8e9f557/_configtest.c:6: undefined reference to `exp'
#             collect2: error: ld returned 1 exit status
#             failure.
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c:1:5: warning: conflicting types for built-in function ‘exp’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#                 1 | int exp (void);
#                   |     ^~~
#             _configtest.c:1:1: note: ‘exp’ is declared in header ‘<math.h>’
#               +++ |+#include <math.h>
#                 1 | int exp (void);
#             x86_64-linux-gnu-gcc _configtest.o -lm -o _configtest
#             success!
#             removing: _configtest.c _configtest.o _configtest.o.d _configtest
#             creating build/src.linux-x86_64-3.1/numpy/core
#             creating build/src.linux-x86_64-3.1/numpy/core/src
#             creating build/src.linux-x86_64-3.1/numpy/core/src/npymath
#             conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npymath/npy_math_internal.h
#               adding 'build/src.linux-x86_64-3.1/numpy/core/src/npymath' to include_dirs.
#             conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npymath/ieee754.c
#             conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npymath/npy_math_complex.c
#             None - nothing done with h_files = ['build/src.linux-x86_64-3.1/numpy/core/src/npymath/npy_math_internal.h']
#             building library "npysort" sources
#             creating build/src.linux-x86_64-3.1/numpy/core/src/common
#             conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/common/npy_sort.h
#               adding 'build/src.linux-x86_64-3.1/numpy/core/src/common' to include_dirs.
#             creating build/src.linux-x86_64-3.1/numpy/core/src/npysort
#             conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npysort/quicksort.c
#             conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npysort/mergesort.c
#             conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npysort/timsort.c
#             conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npysort/heapsort.c
#             conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npysort/radixsort.c
#             conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/common/npy_partition.h
#             conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npysort/selection.c
#             conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/common/npy_binsearch.h
#             conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npysort/binsearch.c
#             None - nothing done with h_files = ['build/src.linux-x86_64-3.1/numpy/core/src/common/npy_sort.h', 'build/src.linux-x86_64-3.1/numpy/core/src/common/npy_partition.h', 'build/src.linux-x86_64-3.1/numpy/core/src/common/npy_binsearch.h']
#             building extension "numpy.core._dummy" sources
#             Generating build/src.linux-x86_64-3.1/numpy/core/include/numpy/config.h
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             success!
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             success!
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c:1:10: fatal error: sys/endian.h: No such file or directory
#                 1 | #include <sys/endian.h>
#                   |          ^~~~~~~~~~~~~~
#             compilation terminated.
#             failure.
#             removing: _configtest.c _configtest.o
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             success!
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             success!
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             success!
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             success!
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c: In function ‘main’:
#             _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#                 5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) >= 0)];
#                   |                ^~~~~~~~~~
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c: In function ‘main’:
#             _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#                 5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) == 4)];
#                   |                ^~~~~~~~~~
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c: In function ‘main’:
#             _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#                 5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) >= 0)];
#                   |                ^~~~~~~~~~
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c: In function ‘main’:
#             _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#                 5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) == 8)];
#                   |                ^~~~~~~~~~
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             success!
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c: In function ‘main’:
#             _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#                 5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) >= 0)];
#                   |                ^~~~~~~~~~
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c: In function ‘main’:
#             _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#                 5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) == 8)];
#                   |                ^~~~~~~~~~
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c: In function ‘main’:
#             _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#                 5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) >= 0)];
#                   |                ^~~~~~~~~~
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c: In function ‘main’:
#             _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#                 5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) == 16)];
#                   |                ^~~~~~~~~~
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c: In function ‘main’:
#             _configtest.c:7:12: error: ‘SIZEOF_LONGDOUBLE’ undeclared (first use in this function); did you mean ‘SIZEOF_LONG_DOUBLE’?
#                 7 |     (void) SIZEOF_LONGDOUBLE;
#                   |            ^~~~~~~~~~~~~~~~~
#                   |            SIZEOF_LONG_DOUBLE
#             _configtest.c:7:12: note: each undeclared identifier is reported only once for each function it appears in
#             failure.
#             removing: _configtest.c _configtest.o
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c: In function ‘main’:
#             _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#                 5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) >= 0)];
#                   |                ^~~~~~~~~~
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c: In function ‘main’:
#             _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#                 5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) == 16)];
#                   |                ^~~~~~~~~~
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c: In function ‘main’:
#             _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#                 5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) >= 0)];
#                   |                ^~~~~~~~~~
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c: In function ‘main’:
#             _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#                 5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) == 32)];
#                   |                ^~~~~~~~~~
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c: In function ‘main’:
#             _configtest.c:7:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#                 7 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) >= 0)];
#                   |                ^~~~~~~~~~
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c: In function ‘main’:
#             _configtest.c:7:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#                 7 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) == 8)];
#                   |                ^~~~~~~~~~
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c: In function ‘main’:
#             _configtest.c:7:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#                 7 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) >= 0)];
#                   |                ^~~~~~~~~~
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c: In function ‘main’:
#             _configtest.c:7:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#                 7 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) == 8)];
#                   |                ^~~~~~~~~~
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             success!
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c: In function ‘main’:
#             _configtest.c:7:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#                 7 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) >= 0)];
#                   |                ^~~~~~~~~~
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c: In function ‘main’:
#             _configtest.c:7:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#                 7 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) == 8)];
#                   |                ^~~~~~~~~~
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c: In function ‘main’:
#             _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#                 5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) >= 0)];
#                   |                ^~~~~~~~~~
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c: In function ‘main’:
#             _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#                 5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) == 8)];
#                   |                ^~~~~~~~~~
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             success!
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c:1:5: warning: conflicting types for built-in function ‘exp’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#                 1 | int exp (void);
#                   |     ^~~
#             _configtest.c:1:1: note: ‘exp’ is declared in header ‘<math.h>’
#               +++ |+#include <math.h>
#                 1 | int exp (void);
#             x86_64-linux-gnu-gcc _configtest.o -o _configtest
#             /usr/bin/ld: _configtest.o: in function `main':
#             /tmp/pip-install-m3epvlos/numpy_e0b647e5fe12423cb444c53cf8e9f557/_configtest.c:6: undefined reference to `exp'
#             collect2: error: ld returned 1 exit status
#             failure.
#             removing: _configtest.c _configtest.o _configtest.o.d
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c:1:5: warning: conflicting types for built-in function ‘exp’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#                 1 | int exp (void);
#                   |     ^~~
#             _configtest.c:1:1: note: ‘exp’ is declared in header ‘<math.h>’
#               +++ |+#include <math.h>
#                 1 | int exp (void);
#             x86_64-linux-gnu-gcc _configtest.o -lm -o _configtest
#             success!
#             removing: _configtest.c _configtest.o _configtest.o.d _configtest
#             C compiler: x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#             compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -c'
#             x86_64-linux-gnu-gcc: _configtest.c
#             _configtest.c:1:5: warning: conflicting types for built-in function ‘sin’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#                 1 | int sin (void);
#                   |     ^~~
#             _configtest.c:1:1: note: ‘sin’ is declared in header ‘<math.h>’
#               +++ |+#include <math.h>
#                 1 | int sin (void);
#             _configtest.c:2:5: warning: conflicting types for built-in function ‘cos’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#                 2 | int cos (void);
#                   |     ^~~
#             _configtest.c:2:5: note: ‘cos’ is declared in header ‘<math.h>’
#             _configtest.c:3:5: warning: conflicting types for built-in function ‘tan’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#                 3 | int tan (void);
#                   |     ^~~
#             _configtest.c:3:5: note: ‘tan’ is declared in header ‘<math.h>’
#             _configtest.c:4:5: warning: conflicting types for built-in function ‘sinh’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#                 4 | int sinh (void);
#                   |     ^~~~
#             _configtest.c:4:5: note: ‘sinh’ is declared in header ‘<math.h>’
#             _configtest.c:5:5: warning: conflicting types for built-in function ‘cosh’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#                 5 | int cosh (void);
#                   |     ^~~~
#             _configtest.c:5:5: note: ‘cosh’ is declared in header ‘<math.h>’
#             _configtest.c:6:5: warning: conflicting types for built-in function ‘tanh’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#                 6 | int tanh (void);
#                   |     ^~~~
#             _configtest.c:6:5: note: ‘tanh’ is declared in header ‘<math.h>’
#             _configtest.c:7:5: warning: conflicting types for built-in function ‘fabs’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#                 7 | int fabs (void);
#                   |     ^~~~
#             _configtest.c:7:5: note: ‘fabs’ is declared in header ‘<math.h>’
#             _configtest.c:8:5: warning: conflicting types for built-in function ‘floor’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#                 8 | int floor (void);
#                   |     ^~~~~
#             _configtest.c:8:5: note: ‘floor’ is declared in header ‘<math.h>’
#             _configtest.c:9:5: warning: conflicting types for built-in function ‘ceil’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#                 9 | int ceil (void);
#                   |     ^~~~
#             _configtest.c:9:5: note: ‘ceil’ is declared in header ‘<math.h>’
#             _configtest.c:10:5: warning: conflicting types for built-in function ‘sqrt’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#                10 | int sqrt (void);
#                   |     ^~~~
#             _configtest.c:10:5: note: ‘sqrt’ is declared in header ‘<math.h>’
#             _configtest.c:11:5: warning: conflicting types for built-in function ‘log10’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#                11 | int log10 (void);
#                   |     ^~~~~
#             _configtest.c:11:5: note: ‘log10’ is declared in header ‘<math.h>’
#             _configtest.c:12:5: warning: conflicting types for built-in function ‘log’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#                12 | int log (void);
#                   |     ^~~
#             _configtest.c:12:5: note: ‘log’ is declared in header ‘<math.h>’
#             _configtest.c:13:5: warning: conflicting types for built-in function ‘exp’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#                13 | int exp (void);
#                   |     ^~~
#             _configtest.c:13:5: note: ‘exp’ is declared in header ‘<math.h>’
#             _configtest.c:14:5: warning: conflicting types for built-in function ‘asin’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#                14 | int asin (void);
#                   |     ^~~~
#             _configtest.c:14:5: note: ‘asin’ is declared in header ‘<math.h>’
#             _configtest.c:15:5: warning: conflicting types for built-in function ‘acos’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#                15 | int acos (void);
#                   |     ^~~~
#             _configtest.c:15:5: note: ‘acos’ is declared in header ‘<math.h>’
#             _configtest.c:16:5: warning: conflicting types for built-in function ‘atan’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#                16 | int atan (void);
#                   |     ^~~~
#             _configtest.c:16:5: note: ‘atan’ is declared in header ‘<math.h>’
#             _configtest.c:17:5: warning: conflicting types for built-in function ‘fmod’; expected ‘double(double,  double)’ [-Wbuiltin-declaration-mismatch]
#                17 | int fmod (void);
#                   |     ^~~~
#             _configtest.c:17:5: note: ‘fmod’ is declared in header ‘<math.h>’
#             _configtest.c:18:5: warning: conflicting types for built-in function ‘modf’; expected ‘double(double,  double *)’ [-Wbuiltin-declaration-mismatch]
#                18 | int modf (void);
#                   |     ^~~~
#             _configtest.c:18:5: note: ‘modf’ is declared in header ‘<math.h>’
#             _configtest.c:19:5: warning: conflicting types for built-in function ‘frexp’; expected ‘double(double,  int *)’ [-Wbuiltin-declaration-mismatch]
#                19 | int frexp (void);
#                   |     ^~~~~
#             _configtest.c:19:5: note: ‘frexp’ is declared in header ‘<math.h>’
# ...
#              1850 |         buflen = PyUnicode_GET_DATA_SIZE(self);
#                   |         ^~~~~~
#             In file included from /usr/include/python3.10/unicodeobject.h:1046,
#                              from /usr/include/python3.10/Python.h:83,
#                              from numpy/core/src/multiarray/scalartypes.c.src:3:
#             /usr/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#               446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                   |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             numpy/core/src/multiarray/scalartypes.c.src:1850:9: warning: ‘PyUnicode_AsUnicode’ is deprecated [-Wdeprecated-declarations]
#              1850 |         buflen = PyUnicode_GET_DATA_SIZE(self);
#                   |         ^~~~~~
#             In file included from /usr/include/python3.10/unicodeobject.h:1046,
#                              from /usr/include/python3.10/Python.h:83,
#                              from numpy/core/src/multiarray/scalartypes.c.src:3:
#             /usr/include/python3.10/cpython/unicodeobject.h:580:45: note: declared here
#               580 | Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#                   |                                             ^~~~~~~~~~~~~~~~~~~
#             numpy/core/src/multiarray/scalartypes.c.src:1850:9: warning: ‘_PyUnicode_get_wstr_length’ is deprecated [-Wdeprecated-declarations]
#              1850 |         buflen = PyUnicode_GET_DATA_SIZE(self);
#                   |         ^~~~~~
#             In file included from /usr/include/python3.10/unicodeobject.h:1046,
#                              from /usr/include/python3.10/Python.h:83,
#                              from numpy/core/src/multiarray/scalartypes.c.src:3:
#             /usr/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#               446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                   |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             numpy/core/src/multiarray/scalartypes.c.src: In function ‘float_arrtype_hash’:
#             numpy/core/src/multiarray/scalartypes.c.src:3311:27: error: incompatible type for argument 1 of ‘_Py_HashDouble’
#              3311 |     return _Py_HashDouble((double) ((Py@name@ScalarObject *)obj)->obval);
#                   |                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                   |                           |
#                   |                           double
#             In file included from /usr/include/python3.10/Python.h:77,
#                              from numpy/core/src/multiarray/scalartypes.c.src:3:
#             /usr/include/python3.10/pyhash.h:10:38: note: expected ‘PyObject *’ {aka ‘struct _object *’} but argument is of type ‘double’
#                10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#                   |                                      ^~~~~~~~~~
#             numpy/core/src/multiarray/scalartypes.c.src:3311:12: error: too few arguments to function ‘_Py_HashDouble’
#              3311 |     return _Py_HashDouble((double) ((Py@name@ScalarObject *)obj)->obval);
#                   |            ^~~~~~~~~~~~~~
#             In file included from /usr/include/python3.10/Python.h:77,
#                              from numpy/core/src/multiarray/scalartypes.c.src:3:
#             /usr/include/python3.10/pyhash.h:10:23: note: declared here
#                10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#                   |                       ^~~~~~~~~~~~~~
#             numpy/core/src/multiarray/scalartypes.c.src: In function ‘cfloat_arrtype_hash’:
#             numpy/core/src/multiarray/scalartypes.c.src:3319:31: error: incompatible type for argument 1 of ‘_Py_HashDouble’
#              3319 |     hashreal = _Py_HashDouble((double)
#                   |                               ^~~~~~~~
#                   |                               |
#                   |                               double
#              3320 |             (((PyC@name@ScalarObject *)obj)->obval).real);
#                   |             ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             In file included from /usr/include/python3.10/Python.h:77,
#                              from numpy/core/src/multiarray/scalartypes.c.src:3:
#             /usr/include/python3.10/pyhash.h:10:38: note: expected ‘PyObject *’ {aka ‘struct _object *’} but argument is of type ‘double’
#                10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#                   |                                      ^~~~~~~~~~
#             numpy/core/src/multiarray/scalartypes.c.src:3319:16: error: too few arguments to function ‘_Py_HashDouble’
#              3319 |     hashreal = _Py_HashDouble((double)
#                   |                ^~~~~~~~~~~~~~
#             In file included from /usr/include/python3.10/Python.h:77,
#                              from numpy/core/src/multiarray/scalartypes.c.src:3:
#             /usr/include/python3.10/pyhash.h:10:23: note: declared here
#                10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#                   |                       ^~~~~~~~~~~~~~
#             numpy/core/src/multiarray/scalartypes.c.src:3325:31: error: incompatible type for argument 1 of ‘_Py_HashDouble’
#              3325 |     hashimag = _Py_HashDouble((double)
#                   |                               ^~~~~~~~
#                   |                               |
#                   |                               double
#              3326 |             (((PyC@name@ScalarObject *)obj)->obval).imag);
#                   |             ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             In file included from /usr/include/python3.10/Python.h:77,
#                              from numpy/core/src/multiarray/scalartypes.c.src:3:
#             /usr/include/python3.10/pyhash.h:10:38: note: expected ‘PyObject *’ {aka ‘struct _object *’} but argument is of type ‘double’
#                10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#                   |                                      ^~~~~~~~~~
#             numpy/core/src/multiarray/scalartypes.c.src:3325:16: error: too few arguments to function ‘_Py_HashDouble’
#              3325 |     hashimag = _Py_HashDouble((double)
#                   |                ^~~~~~~~~~~~~~
#             In file included from /usr/include/python3.10/Python.h:77,
#                              from numpy/core/src/multiarray/scalartypes.c.src:3:
#             /usr/include/python3.10/pyhash.h:10:23: note: declared here
#                10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#                   |                       ^~~~~~~~~~~~~~
#             numpy/core/src/multiarray/scalartypes.c.src: In function ‘longdouble_arrtype_hash’:
#             numpy/core/src/multiarray/scalartypes.c.src:3311:27: error: incompatible type for argument 1 of ‘_Py_HashDouble’
#              3311 |     return _Py_HashDouble((double) ((Py@name@ScalarObject *)obj)->obval);
#                   |                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                   |                           |
#                   |                           double
#             In file included from /usr/include/python3.10/Python.h:77,
#                              from numpy/core/src/multiarray/scalartypes.c.src:3:
#             /usr/include/python3.10/pyhash.h:10:38: note: expected ‘PyObject *’ {aka ‘struct _object *’} but argument is of type ‘double’
#                10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#                   |                                      ^~~~~~~~~~
#             numpy/core/src/multiarray/scalartypes.c.src:3311:12: error: too few arguments to function ‘_Py_HashDouble’
#              3311 |     return _Py_HashDouble((double) ((Py@name@ScalarObject *)obj)->obval);
#                   |            ^~~~~~~~~~~~~~
#             In file included from /usr/include/python3.10/Python.h:77,
#                              from numpy/core/src/multiarray/scalartypes.c.src:3:
#             /usr/include/python3.10/pyhash.h:10:23: note: declared here
#                10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#                   |                       ^~~~~~~~~~~~~~
#             numpy/core/src/multiarray/scalartypes.c.src: In function ‘clongdouble_arrtype_hash’:
#             numpy/core/src/multiarray/scalartypes.c.src:3319:31: error: incompatible type for argument 1 of ‘_Py_HashDouble’
#              3319 |     hashreal = _Py_HashDouble((double)
#                   |                               ^~~~~~~~
#                   |                               |
#                   |                               double
#              3320 |             (((PyC@name@ScalarObject *)obj)->obval).real);
#                   |             ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             In file included from /usr/include/python3.10/Python.h:77,
#                              from numpy/core/src/multiarray/scalartypes.c.src:3:
#             /usr/include/python3.10/pyhash.h:10:38: note: expected ‘PyObject *’ {aka ‘struct _object *’} but argument is of type ‘double’
#                10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#                   |                                      ^~~~~~~~~~
#             numpy/core/src/multiarray/scalartypes.c.src:3319:16: error: too few arguments to function ‘_Py_HashDouble’
#              3319 |     hashreal = _Py_HashDouble((double)
#                   |                ^~~~~~~~~~~~~~
#             In file included from /usr/include/python3.10/Python.h:77,
#                              from numpy/core/src/multiarray/scalartypes.c.src:3:
#             /usr/include/python3.10/pyhash.h:10:23: note: declared here
#                10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#                   |                       ^~~~~~~~~~~~~~
#             numpy/core/src/multiarray/scalartypes.c.src:3325:31: error: incompatible type for argument 1 of ‘_Py_HashDouble’
#              3325 |     hashimag = _Py_HashDouble((double)
#                   |                               ^~~~~~~~
#                   |                               |
#                   |                               double
#              3326 |             (((PyC@name@ScalarObject *)obj)->obval).imag);
#                   |             ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             In file included from /usr/include/python3.10/Python.h:77,
#                              from numpy/core/src/multiarray/scalartypes.c.src:3:
#             /usr/include/python3.10/pyhash.h:10:38: note: expected ‘PyObject *’ {aka ‘struct _object *’} but argument is of type ‘double’
#                10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#                   |                                      ^~~~~~~~~~
#             numpy/core/src/multiarray/scalartypes.c.src:3325:16: error: too few arguments to function ‘_Py_HashDouble’
#              3325 |     hashimag = _Py_HashDouble((double)
#                   |                ^~~~~~~~~~~~~~
#             In file included from /usr/include/python3.10/Python.h:77,
#                              from numpy/core/src/multiarray/scalartypes.c.src:3:
#             /usr/include/python3.10/pyhash.h:10:23: note: declared here
#                10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#                   |                       ^~~~~~~~~~~~~~
#             numpy/core/src/multiarray/scalartypes.c.src: In function ‘half_arrtype_hash’:
#             numpy/core/src/multiarray/scalartypes.c.src:3341:27: error: incompatible type for argument 1 of ‘_Py_HashDouble’
#              3341 |     return _Py_HashDouble(npy_half_to_double(((PyHalfScalarObject *)obj)->obval));
#                   |                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                   |                           |
#                   |                           double
#             In file included from /usr/include/python3.10/Python.h:77,
#                              from numpy/core/src/multiarray/scalartypes.c.src:3:
#             /usr/include/python3.10/pyhash.h:10:38: note: expected ‘PyObject *’ {aka ‘struct _object *’} but argument is of type ‘double’
#                10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#                   |                                      ^~~~~~~~~~
#             numpy/core/src/multiarray/scalartypes.c.src:3341:12: error: too few arguments to function ‘_Py_HashDouble’
#              3341 |     return _Py_HashDouble(npy_half_to_double(((PyHalfScalarObject *)obj)->obval));
#                   |            ^~~~~~~~~~~~~~
#             In file included from /usr/include/python3.10/Python.h:77,
#                              from numpy/core/src/multiarray/scalartypes.c.src:3:
#             /usr/include/python3.10/pyhash.h:10:23: note: declared here
#                10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#                   |                       ^~~~~~~~~~~~~~
#             numpy/core/src/multiarray/scalartypes.c.src: In function ‘longdouble_arrtype_hash’:
#             numpy/core/src/multiarray/scalartypes.c.src:3312:1: warning: control reaches end of non-void function [-Wreturn-type]
#              3312 | }
#                   | ^
#             numpy/core/src/multiarray/scalartypes.c.src: In function ‘float_arrtype_hash’:
#             numpy/core/src/multiarray/scalartypes.c.src:3312:1: warning: control reaches end of non-void function [-Wreturn-type]
#              3312 | }
#                   | ^
#             numpy/core/src/multiarray/scalartypes.c.src: In function ‘half_arrtype_hash’:
#             numpy/core/src/multiarray/scalartypes.c.src:3342:1: warning: control reaches end of non-void function [-Wreturn-type]
#              3342 | }
#                   | ^
#             error: Command "x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -DNPY_INTERNAL_BUILD=1 -DHAVE_NPY_CONFIG_H=1 -D_FILE_OFFSET_BITS=64 -D_LARGEFILE_SOURCE=1 -D_LARGEFILE64_SOURCE=1 -DHAVE_CBLAS -Ibuild/src.linux-x86_64-3.1/numpy/core/src/umath -Ibuild/src.linux-x86_64-3.1/numpy/core/src/npymath -Ibuild/src.linux-x86_64-3.1/numpy/core/src/common -Inumpy/core/include -Ibuild/src.linux-x86_64-3.1/numpy/core/include/numpy -Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.10 -Ibuild/src.linux-x86_64-3.1/numpy/core/src/common -Ibuild/src.linux-x86_64-3.1/numpy/core/src/npymath -Ibuild/src.linux-x86_64-3.1/numpy/core/src/common -Ibuild/src.linux-x86_64-3.1/numpy/core/src/npymath -c build/src.linux-x86_64-3.1/numpy/core/src/multiarray/scalartypes.c -o build/temp.linux-x86_64-3.10/build/src.linux-x86_64-3.1/numpy/core/src/multiarray/scalartypes.o -MMD -MF build/temp.linux-x86_64-3.10/build/src.linux-x86_64-3.1/numpy/core/src/multiarray/scalartypes.o.d" failed with exit status 1
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#       error: legacy-install-failure
#
#       × Encountered error while trying to install package.
#       ╰─> numpy
#
#       note: This is an issue with the package mentioned above, not pip.
#       hint: See above for output from the failure.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × pip subprocess to install build dependencies did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
pip install numpy==1.19.5
# Out:
# /usr/local/lib/python3.6/pty.py:84: ResourceWarning: Unclosed socket <zmq.Socket(zmq.PUSH) at 0x7bab4c2ff0f0>
#   pid, fd = os.forkpty()
# Collecting numpy==1.19.5
#   Using cached https://files.pythonhosted.org/packages/51/60/3f0fe5b7675a461d96b9d6729beecd3532565743278a9c3fe6dd09697fa7/numpy-1.19.5.zip
#   Installing build dependencies ... done
# Installing collected packages: numpy
#   Running setup.py install for numpy ... error
#     Complete output from command /usr/local/bin/python3.6 -u -c "import setuptools, tokenize;__file__='/tmp/pip-install-l62xwzdo/numpy/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" install --record /tmp/pip-record-dzr19baa/install-record.txt --single-version-externally-managed --compile:
#     Running from numpy source directory.
#
#     Note: if you need reliable uninstall behavior, then install
#     with pip instead of using `setup.py install`:
#
#       - `pip install .`       (from a git repo or downloaded source
#                                release)
#       - `pip install numpy`   (last NumPy release on PyPi)
#
#
#     Cythonizing sources
#     Processing numpy/random/_bounded_integers.pxd.in
#     Processing numpy/random/bit_generator.pyx
#     Processing numpy/random/_bounded_integers.pyx.in
#     Processing numpy/random/mtrand.pyx
#     Processing numpy/random/_philox.pyx
#     Processing numpy/random/_sfc64.pyx
#     Processing numpy/random/_pcg64.pyx
#     Processing numpy/random/_mt19937.pyx
#     Processing numpy/random/_common.pyx
#     Processing numpy/random/_generator.pyx
#     blas_opt_info:
#     blas_mkl_info:
#     customize UnixCCompiler
#       libraries mkl_rt not found in ['/usr/local/lib', '/usr/lib64', '/usr/lib', '/usr/lib/x86_64-linux-gnu']
#       NOT AVAILABLE
#
#     blis_info:
#       libraries blis not found in ['/usr/local/lib', '/usr/lib64', '/usr/lib', '/usr/lib/x86_64-linux-gnu']
#       NOT AVAILABLE
#
#     openblas_info:
#     C compiler: gcc -Wno-unused-result -Wsign-compare -g -Og -Wall -fPIC
#
#     creating /tmp/tmp4w5m1dor/tmp
#     creating /tmp/tmp4w5m1dor/tmp/tmp4w5m1dor
#     compile options: '-c'
#     gcc: /tmp/tmp4w5m1dor/source.c
#     gcc /tmp/tmp4w5m1dor/tmp/tmp4w5m1dor/source.o -L/usr/lib/x86_64-linux-gnu -lopenblas -o /tmp/tmp4w5m1dor/a.out
#       FOUND:
#         libraries = ['openblas', 'openblas']
#         library_dirs = ['/usr/lib/x86_64-linux-gnu']
#         language = c
#         define_macros = [('HAVE_CBLAS', None)]
#
#       FOUND:
#         libraries = ['openblas', 'openblas']
#         library_dirs = ['/usr/lib/x86_64-linux-gnu']
#         language = c
#         define_macros = [('HAVE_CBLAS', None)]
#
#     non-existing path in 'numpy/distutils': 'site.cfg'
#     lapack_opt_info:
#     lapack_mkl_info:
#       libraries mkl_rt not found in ['/usr/local/lib', '/usr/lib64', '/usr/lib', '/usr/lib/x86_64-linux-gnu']
#       NOT AVAILABLE
#
#     openblas_lapack_info:
#     C compiler: gcc -Wno-unused-result -Wsign-compare -g -Og -Wall -fPIC
#
#     creating /tmp/tmp08t3zgxe/tmp
#     creating /tmp/tmp08t3zgxe/tmp/tmp08t3zgxe
#     compile options: '-c'
#     gcc: /tmp/tmp08t3zgxe/source.c
#     gcc /tmp/tmp08t3zgxe/tmp/tmp08t3zgxe/source.o -L/usr/lib/x86_64-linux-gnu -lopenblas -o /tmp/tmp08t3zgxe/a.out
#       FOUND:
#         libraries = ['openblas', 'openblas']
#         library_dirs = ['/usr/lib/x86_64-linux-gnu']
#         language = c
#         define_macros = [('HAVE_CBLAS', None)]
#
#       FOUND:
#         libraries = ['openblas', 'openblas']
#         library_dirs = ['/usr/lib/x86_64-linux-gnu']
#         language = c
#         define_macros = [('HAVE_CBLAS', None)]
#
#     /usr/local/lib/python3.6/distutils/dist.py:261: UserWarning: Unknown distribution option: 'define_macros'
#       warnings.warn(msg)
#     running install
#     running build
#     running config_cc
#     unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#     running config_fc
#     unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#     running build_src
#     build_src
#     building py_modules sources
#     creating build
#     creating build/src.linux-x86_64-3.6
#     creating build/src.linux-x86_64-3.6/numpy
#     creating build/src.linux-x86_64-3.6/numpy/distutils
#     building library "npymath" sources
#     Could not locate executable gfortran
#     Could not locate executable f95
#     Could not locate executable ifort
#     Could not locate executable ifc
#     Could not locate executable lf95
#     Could not locate executable pgfortran
#     Could not locate executable nvfortran
#     Could not locate executable f90
#     Could not locate executable f77
#     Could not locate executable fort
#     Could not locate executable efort
#     Could not locate executable efc
#     Could not locate executable g77
#     Could not locate executable g95
#     Could not locate executable pathf95
#     Could not locate executable nagfor
#     don't know how to compile Fortran code on platform 'posix'
#     creating build/src.linux-x86_64-3.6/numpy/core
#     creating build/src.linux-x86_64-3.6/numpy/core/src
#     creating build/src.linux-x86_64-3.6/numpy/core/src/npymath
#     conv_template:> build/src.linux-x86_64-3.6/numpy/core/src/npymath/npy_math_internal.h
#       adding 'build/src.linux-x86_64-3.6/numpy/core/src/npymath' to include_dirs.
#     conv_template:> build/src.linux-x86_64-3.6/numpy/core/src/npymath/ieee754.c
#     conv_template:> build/src.linux-x86_64-3.6/numpy/core/src/npymath/npy_math_complex.c
#     None - nothing done with h_files = ['build/src.linux-x86_64-3.6/numpy/core/src/npymath/npy_math_internal.h']
#     building library "npysort" sources
#     creating build/src.linux-x86_64-3.6/numpy/core/src/common
#     conv_template:> build/src.linux-x86_64-3.6/numpy/core/src/common/npy_sort.h
#       adding 'build/src.linux-x86_64-3.6/numpy/core/src/common' to include_dirs.
#     creating build/src.linux-x86_64-3.6/numpy/core/src/npysort
#     conv_template:> build/src.linux-x86_64-3.6/numpy/core/src/npysort/quicksort.c
#     conv_template:> build/src.linux-x86_64-3.6/numpy/core/src/npysort/mergesort.c
#     conv_template:> build/src.linux-x86_64-3.6/numpy/core/src/npysort/timsort.c
#     conv_template:> build/src.linux-x86_64-3.6/numpy/core/src/npysort/heapsort.c
#     conv_template:> build/src.linux-x86_64-3.6/numpy/core/src/npysort/radixsort.c
#     conv_template:> build/src.linux-x86_64-3.6/numpy/core/src/common/npy_partition.h
#     conv_template:> build/src.linux-x86_64-3.6/numpy/core/src/npysort/selection.c
#     conv_template:> build/src.linux-x86_64-3.6/numpy/core/src/common/npy_binsearch.h
#     conv_template:> build/src.linux-x86_64-3.6/numpy/core/src/npysort/binsearch.c
#     None - nothing done with h_files = ['build/src.linux-x86_64-3.6/numpy/core/src/common/npy_sort.h', 'build/src.linux-x86_64-3.6/numpy/core/src/common/npy_partition.h', 'build/src.linux-x86_64-3.6/numpy/core/src/common/npy_binsearch.h']
#     building library "npyrandom" sources
#     building extension "numpy.core._multiarray_tests" sources
#     creating build/src.linux-x86_64-3.6/numpy/core/src/multiarray
#     conv_template:> build/src.linux-x86_64-3.6/numpy/core/src/multiarray/_multiarray_tests.c
#     building extension "numpy.core._multiarray_umath" sources
#     conv_template:> build/src.linux-x86_64-3.6/numpy/core/src/multiarray/arraytypes.c
#     conv_template:> build/src.linux-x86_64-3.6/numpy/core/src/multiarray/einsum.c
#     conv_template:> build/src.linux-x86_64-3.6/numpy/core/src/multiarray/lowlevel_strided_loops.c
#     conv_template:> build/src.linux-x86_64-3.6/numpy/core/src/multiarray/nditer_templ.c
#     conv_template:> build/src.linux-x86_64-3.6/numpy/core/src/multiarray/scalartypes.c
#     creating build/src.linux-x86_64-3.6/numpy/core/src/umath
#     conv_template:> build/src.linux-x86_64-3.6/numpy/core/src/umath/funcs.inc
#       adding 'build/src.linux-x86_64-3.6/numpy/core/src/umath' to include_dirs.
#     conv_template:> build/src.linux-x86_64-3.6/numpy/core/src/umath/simd.inc
#     conv_template:> build/src.linux-x86_64-3.6/numpy/core/src/umath/loops.h
#     conv_template:> build/src.linux-x86_64-3.6/numpy/core/src/umath/loops.c
#     conv_template:> build/src.linux-x86_64-3.6/numpy/core/src/umath/matmul.h
#     conv_template:> build/src.linux-x86_64-3.6/numpy/core/src/umath/matmul.c
#     conv_template:> build/src.linux-x86_64-3.6/numpy/core/src/umath/clip.h
#     conv_template:> build/src.linux-x86_64-3.6/numpy/core/src/umath/clip.c
#     conv_template:> build/src.linux-x86_64-3.6/numpy/core/src/umath/scalarmath.c
#       adding 'build/src.linux-x86_64-3.6/numpy/core/src/npymath' to include_dirs.
#     conv_template:> build/src.linux-x86_64-3.6/numpy/core/src/common/templ_common.h
#       adding 'build/src.linux-x86_64-3.6/numpy/core/src/common' to include_dirs.
#     conv_template:> build/src.linux-x86_64-3.6/numpy/core/src/common/npy_cpu_features.c
#     numpy.core - nothing done with h_files = ['build/src.linux-x86_64-3.6/numpy/core/src/umath/funcs.inc', 'build/src.linux-x86_64-3.6/numpy/core/src/umath/simd.inc', 'build/src.linux-x86_64-3.6/numpy/core/src/umath/loops.h', 'build/src.linux-x86_64-3.6/numpy/core/src/umath/matmul.h', 'build/src.linux-x86_64-3.6/numpy/core/src/umath/clip.h', 'build/src.linux-x86_64-3.6/numpy/core/src/npymath/npy_math_internal.h', 'build/src.linux-x86_64-3.6/numpy/core/src/common/templ_common.h', 'build/src.linux-x86_64-3.6/numpy/core/include/numpy/config.h', 'build/src.linux-x86_64-3.6/numpy/core/include/numpy/_numpyconfig.h', 'build/src.linux-x86_64-3.6/numpy/core/include/numpy/__multiarray_api.h', 'build/src.linux-x86_64-3.6/numpy/core/include/numpy/__ufunc_api.h']
#     building extension "numpy.core._umath_tests" sources
#     conv_template:> build/src.linux-x86_64-3.6/numpy/core/src/umath/_umath_tests.c
#     building extension "numpy.core._rational_tests" sources
#     conv_template:> build/src.linux-x86_64-3.6/numpy/core/src/umath/_rational_tests.c
#     building extension "numpy.core._struct_ufunc_tests" sources
#     conv_template:> build/src.linux-x86_64-3.6/numpy/core/src/umath/_struct_ufunc_tests.c
#     building extension "numpy.core._operand_flag_tests" sources
#     conv_template:> build/src.linux-x86_64-3.6/numpy/core/src/umath/_operand_flag_tests.c
#     building extension "numpy.fft._pocketfft_internal" sources
#     building extension "numpy.linalg.lapack_lite" sources
#     creating build/src.linux-x86_64-3.6/numpy/linalg
#     building extension "numpy.linalg._umath_linalg" sources
#     conv_template:> build/src.linux-x86_64-3.6/numpy/linalg/umath_linalg.c
#     building extension "numpy.random._mt19937" sources
#     building extension "numpy.random._philox" sources
#     building extension "numpy.random._pcg64" sources
#     building extension "numpy.random._sfc64" sources
#     building extension "numpy.random._common" sources
#     building extension "numpy.random.bit_generator" sources
#     building extension "numpy.random._generator" sources
#     building extension "numpy.random._bounded_integers" sources
#     building extension "numpy.random.mtrand" sources
#     building data_files sources
#     build_src: building npy-pkg config files
#     running build_py
#     creating build/lib.linux-x86_64-3.6-pydebug
#     creating build/lib.linux-x86_64-3.6-pydebug/numpy
#     copying numpy/__init__.py -> build/lib.linux-x86_64-3.6-pydebug/numpy
#     copying numpy/ctypeslib.py -> build/lib.linux-x86_64-3.6-pydebug/numpy
#     copying numpy/_distributor_init.py -> build/lib.linux-x86_64-3.6-pydebug/numpy
#     copying numpy/_globals.py -> build/lib.linux-x86_64-3.6-pydebug/numpy
#     copying numpy/version.py -> build/lib.linux-x86_64-3.6-pydebug/numpy
#     copying numpy/dual.py -> build/lib.linux-x86_64-3.6-pydebug/numpy
#     copying numpy/matlib.py -> build/lib.linux-x86_64-3.6-pydebug/numpy
#     copying numpy/setup.py -> build/lib.linux-x86_64-3.6-pydebug/numpy
#     copying numpy/_pytesttester.py -> build/lib.linux-x86_64-3.6-pydebug/numpy
#     copying numpy/conftest.py -> build/lib.linux-x86_64-3.6-pydebug/numpy
#     copying build/src.linux-x86_64-3.6/numpy/__config__.py -> build/lib.linux-x86_64-3.6-pydebug/numpy
#     creating build/lib.linux-x86_64-3.6-pydebug/numpy/compat
#     copying numpy/compat/__init__.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/compat
#     copying numpy/compat/py3k.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/compat
#     copying numpy/compat/setup.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/compat
#     copying numpy/compat/_inspect.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/compat
#     creating build/lib.linux-x86_64-3.6-pydebug/numpy/compat/tests
#     copying numpy/compat/tests/__init__.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/compat/tests
#     copying numpy/compat/tests/test_compat.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/compat/tests
#     creating build/lib.linux-x86_64-3.6-pydebug/numpy/core
#     copying numpy/core/__init__.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core
#     copying numpy/core/_type_aliases.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core
#     copying numpy/core/defchararray.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core
#     copying numpy/core/umath_tests.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core
#     copying numpy/core/_dtype.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core
#     copying numpy/core/_ufunc_config.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core
#     copying numpy/core/_asarray.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core
#     copying numpy/core/multiarray.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core
#     copying numpy/core/machar.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core
#     copying numpy/core/getlimits.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core
#     copying numpy/core/numeric.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core
#     copying numpy/core/_add_newdocs.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core
#     copying numpy/core/_internal.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core
#     copying numpy/core/_exceptions.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core
#     copying numpy/core/umath.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core
#     copying numpy/core/fromnumeric.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core
#     copying numpy/core/records.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core
#     copying numpy/core/_methods.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core
#     copying numpy/core/_dtype_ctypes.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core
#     copying numpy/core/einsumfunc.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core
#     copying numpy/core/cversions.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core
#     copying numpy/core/memmap.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core
#     copying numpy/core/setup.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core
#     copying numpy/core/setup_common.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core
#     copying numpy/core/shape_base.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core
#     copying numpy/core/numerictypes.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core
#     copying numpy/core/function_base.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core
#     copying numpy/core/overrides.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core
#     copying numpy/core/_string_helpers.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core
#     copying numpy/core/arrayprint.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core
#     copying numpy/core/code_generators/generate_numpy_api.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core
#     creating build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/__init__.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_extint128.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_scalarmath.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_scalarprint.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_numeric.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_half.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_memmap.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test__exceptions.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_ufunc.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_errstate.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_einsum.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_longdouble.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_item_selection.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_mem_overlap.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_conversion_utils.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/_locales.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_machar.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_function_base.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_unicode.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_scalarbuffer.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_getlimits.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_defchararray.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_deprecations.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_regression.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_print.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_records.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_abc.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_nditer.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_umath_accuracy.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_numerictypes.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_overrides.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_dtype.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_shape_base.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_multiarray.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_scalarinherit.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_indexing.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_protocols.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_api.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_cpu_features.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_arrayprint.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_umath.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_datetime.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_umath_complex.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_scalar_ctors.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_indexerrors.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     copying numpy/core/tests/test_scalar_methods.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/core/tests
#     creating build/lib.linux-x86_64-3.6-pydebug/numpy/distutils
#     copying numpy/distutils/__init__.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils
#     copying numpy/distutils/system_info.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils
#     copying numpy/distutils/extension.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils
#     copying numpy/distutils/line_endings.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils
#     copying numpy/distutils/misc_util.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils
#     copying numpy/distutils/intelccompiler.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils
#     copying numpy/distutils/_shell_utils.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils
#     copying numpy/distutils/npy_pkg_config.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils
#     copying numpy/distutils/conv_template.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils
#     copying numpy/distutils/core.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils
#     copying numpy/distutils/mingw32ccompiler.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils
#     copying numpy/distutils/log.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils
#     copying numpy/distutils/from_template.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils
#     copying numpy/distutils/ccompiler.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils
#     copying numpy/distutils/pathccompiler.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils
#     copying numpy/distutils/lib2def.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils
#     copying numpy/distutils/numpy_distribution.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils
#     copying numpy/distutils/cpuinfo.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils
#     copying numpy/distutils/setup.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils
#     copying numpy/distutils/unixccompiler.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils
#     copying numpy/distutils/msvccompiler.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils
#     copying numpy/distutils/exec_command.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils
#     copying numpy/distutils/msvc9compiler.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils
#     copying build/src.linux-x86_64-3.6/numpy/distutils/__config__.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils
#     creating build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/command
#     copying numpy/distutils/command/__init__.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/command
#     copying numpy/distutils/command/build_py.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/command
#     copying numpy/distutils/command/build_clib.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/command
#     copying numpy/distutils/command/install_clib.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/command
#     copying numpy/distutils/command/build.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/command
#     copying numpy/distutils/command/build_scripts.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/command
#     copying numpy/distutils/command/config_compiler.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/command
#     copying numpy/distutils/command/egg_info.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/command
#     copying numpy/distutils/command/install_data.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/command
#     copying numpy/distutils/command/install_headers.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/command
#     copying numpy/distutils/command/develop.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/command
#     copying numpy/distutils/command/config.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/command
#     copying numpy/distutils/command/autodist.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/command
#     copying numpy/distutils/command/build_src.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/command
#     copying numpy/distutils/command/install.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/command
#     copying numpy/distutils/command/bdist_rpm.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/command
#     copying numpy/distutils/command/sdist.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/command
#     copying numpy/distutils/command/build_ext.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/command
#     creating build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/fcompiler
#     copying numpy/distutils/fcompiler/__init__.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/fcompiler
#     copying numpy/distutils/fcompiler/intel.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/fcompiler
#     copying numpy/distutils/fcompiler/g95.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/fcompiler
#     copying numpy/distutils/fcompiler/ibm.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/fcompiler
#     copying numpy/distutils/fcompiler/nv.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/fcompiler
#     copying numpy/distutils/fcompiler/pathf95.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/fcompiler
#     copying numpy/distutils/fcompiler/absoft.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/fcompiler
#     copying numpy/distutils/fcompiler/pg.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/fcompiler
#     copying numpy/distutils/fcompiler/hpux.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/fcompiler
#     copying numpy/distutils/fcompiler/mips.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/fcompiler
#     copying numpy/distutils/fcompiler/nag.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/fcompiler
#     copying numpy/distutils/fcompiler/sun.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/fcompiler
#     copying numpy/distutils/fcompiler/lahey.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/fcompiler
#     copying numpy/distutils/fcompiler/environment.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/fcompiler
#     copying numpy/distutils/fcompiler/compaq.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/fcompiler
#     copying numpy/distutils/fcompiler/gnu.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/fcompiler
#     copying numpy/distutils/fcompiler/vast.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/fcompiler
#     copying numpy/distutils/fcompiler/none.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/fcompiler
#     creating build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/tests
#     copying numpy/distutils/tests/__init__.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/tests
#     copying numpy/distutils/tests/test_npy_pkg_config.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/tests
#     copying numpy/distutils/tests/test_fcompiler_intel.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/tests
#     copying numpy/distutils/tests/test_exec_command.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/tests
#     copying numpy/distutils/tests/test_shell_utils.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/tests
#     copying numpy/distutils/tests/test_fcompiler.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/tests
#     copying numpy/distutils/tests/test_from_template.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/tests
#     copying numpy/distutils/tests/test_fcompiler_nagfor.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/tests
#     copying numpy/distutils/tests/test_mingw32ccompiler.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/tests
#     copying numpy/distutils/tests/test_fcompiler_gnu.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/tests
#     copying numpy/distutils/tests/test_system_info.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/tests
#     copying numpy/distutils/tests/test_misc_util.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/distutils/tests
#     creating build/lib.linux-x86_64-3.6-pydebug/numpy/doc
#     copying numpy/doc/__init__.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/doc
#     copying numpy/doc/constants.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/doc
#     copying numpy/doc/subclassing.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/doc
#     copying numpy/doc/glossary.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/doc
#     copying numpy/doc/basics.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/doc
#     copying numpy/doc/indexing.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/doc
#     copying numpy/doc/ufuncs.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/doc
#     copying numpy/doc/structured_arrays.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/doc
#     copying numpy/doc/dispatch.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/doc
#     copying numpy/doc/creation.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/doc
#     copying numpy/doc/internals.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/doc
#     copying numpy/doc/misc.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/doc
#     copying numpy/doc/byteswapping.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/doc
#     copying numpy/doc/broadcasting.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/doc
#     creating build/lib.linux-x86_64-3.6-pydebug/numpy/f2py
#     copying numpy/f2py/__init__.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py
#     copying numpy/f2py/auxfuncs.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py
#     copying numpy/f2py/diagnose.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py
#     copying numpy/f2py/use_rules.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py
#     copying numpy/f2py/common_rules.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py
#     copying numpy/f2py/f2py_testing.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py
#     copying numpy/f2py/capi_maps.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py
#     copying numpy/f2py/f2py2e.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py
#     copying numpy/f2py/__version__.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py
#     copying numpy/f2py/rules.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py
#     copying numpy/f2py/cfuncs.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py
#     copying numpy/f2py/f90mod_rules.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py
#     copying numpy/f2py/func2subr.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py
#     copying numpy/f2py/cb_rules.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py
#     copying numpy/f2py/setup.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py
#     copying numpy/f2py/__main__.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py
#     copying numpy/f2py/crackfortran.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py
#     creating build/lib.linux-x86_64-3.6-pydebug/numpy/f2py/tests
#     copying numpy/f2py/tests/test_string.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py/tests
#     copying numpy/f2py/tests/__init__.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py/tests
#     copying numpy/f2py/tests/test_crackfortran.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py/tests
#     copying numpy/f2py/tests/test_return_integer.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py/tests
#     copying numpy/f2py/tests/test_size.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py/tests
#     copying numpy/f2py/tests/test_array_from_pyobj.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py/tests
#     copying numpy/f2py/tests/test_return_logical.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py/tests
#     copying numpy/f2py/tests/test_common.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py/tests
#     copying numpy/f2py/tests/test_parameter.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py/tests
#     copying numpy/f2py/tests/test_return_character.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py/tests
#     copying numpy/f2py/tests/test_block_docstring.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py/tests
#     copying numpy/f2py/tests/test_callback.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py/tests
#     copying numpy/f2py/tests/test_return_real.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py/tests
#     copying numpy/f2py/tests/test_return_complex.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py/tests
#     copying numpy/f2py/tests/test_regression.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py/tests
#     copying numpy/f2py/tests/test_assumed_shape.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py/tests
#     copying numpy/f2py/tests/util.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py/tests
#     copying numpy/f2py/tests/test_quoted_character.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py/tests
#     copying numpy/f2py/tests/test_compile_function.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py/tests
#     copying numpy/f2py/tests/test_semicolon_split.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py/tests
#     copying numpy/f2py/tests/test_mixed.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py/tests
#     copying numpy/f2py/tests/test_kind.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/f2py/tests
#     creating build/lib.linux-x86_64-3.6-pydebug/numpy/fft
#     copying numpy/fft/__init__.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/fft
#     copying numpy/fft/_pocketfft.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/fft
#     copying numpy/fft/setup.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/fft
#     copying numpy/fft/helper.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/fft
#     creating build/lib.linux-x86_64-3.6-pydebug/numpy/fft/tests
#     copying numpy/fft/tests/__init__.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/fft/tests
#     copying numpy/fft/tests/test_helper.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/fft/tests
#     copying numpy/fft/tests/test_pocketfft.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/fft/tests
#     creating build/lib.linux-x86_64-3.6-pydebug/numpy/lib
#     copying numpy/lib/__init__.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib
#     copying numpy/lib/arrayterator.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib
#     copying numpy/lib/scimath.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib
#     copying numpy/lib/financial.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib
#     copying numpy/lib/format.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib
#     copying numpy/lib/utils.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib
#     copying numpy/lib/nanfunctions.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib
#     copying numpy/lib/type_check.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib
#     copying numpy/lib/npyio.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib
#     copying numpy/lib/_iotools.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib
#     copying numpy/lib/recfunctions.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib
#     copying numpy/lib/_datasource.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib
#     copying numpy/lib/twodim_base.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib
#     copying numpy/lib/arraypad.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib
#     copying numpy/lib/histograms.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib
#     copying numpy/lib/user_array.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib
#     copying numpy/lib/ufunclike.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib
#     copying numpy/lib/polynomial.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib
#     copying numpy/lib/_version.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib
#     copying numpy/lib/stride_tricks.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib
#     copying numpy/lib/setup.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib
#     copying numpy/lib/arraysetops.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib
#     copying numpy/lib/mixins.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib
#     copying numpy/lib/shape_base.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib
#     copying numpy/lib/function_base.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib
#     copying numpy/lib/index_tricks.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib
#     creating build/lib.linux-x86_64-3.6-pydebug/numpy/lib/tests
#     copying numpy/lib/tests/__init__.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib/tests
#     copying numpy/lib/tests/test_polynomial.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib/tests
#     copying numpy/lib/tests/test_type_check.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib/tests
#     copying numpy/lib/tests/test_io.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib/tests
#     copying numpy/lib/tests/test_financial.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib/tests
#     copying numpy/lib/tests/test_index_tricks.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib/tests
#     copying numpy/lib/tests/test_function_base.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib/tests
#     copying numpy/lib/tests/test_twodim_base.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib/tests
#     copying numpy/lib/tests/test_arrayterator.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib/tests
#     copying numpy/lib/tests/test_format.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib/tests
#     copying numpy/lib/tests/test_regression.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib/tests
#     copying numpy/lib/tests/test_packbits.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib/tests
#     copying numpy/lib/tests/test_recfunctions.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib/tests
#     copying numpy/lib/tests/test_arraysetops.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib/tests
#     copying numpy/lib/tests/test__datasource.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib/tests
#     copying numpy/lib/tests/test_shape_base.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib/tests
#     copying numpy/lib/tests/test__version.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib/tests
#     copying numpy/lib/tests/test_utils.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib/tests
#     copying numpy/lib/tests/test_nanfunctions.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib/tests
#     copying numpy/lib/tests/test_histograms.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib/tests
#     copying numpy/lib/tests/test_mixins.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib/tests
#     copying numpy/lib/tests/test__iotools.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib/tests
#     copying numpy/lib/tests/test_stride_tricks.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib/tests
#     copying numpy/lib/tests/test_ufunclike.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib/tests
#     copying numpy/lib/tests/test_arraypad.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/lib/tests
#     creating build/lib.linux-x86_64-3.6-pydebug/numpy/linalg
#     copying numpy/linalg/__init__.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/linalg
#     copying numpy/linalg/linalg.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/linalg
#     copying numpy/linalg/setup.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/linalg
#     creating build/lib.linux-x86_64-3.6-pydebug/numpy/linalg/tests
#     copying numpy/linalg/tests/__init__.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/linalg/tests
#     copying numpy/linalg/tests/test_build.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/linalg/tests
#     copying numpy/linalg/tests/test_deprecations.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/linalg/tests
#     copying numpy/linalg/tests/test_regression.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/linalg/tests
#     copying numpy/linalg/tests/test_linalg.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/linalg/tests
#     creating build/lib.linux-x86_64-3.6-pydebug/numpy/ma
#     copying numpy/ma/__init__.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/ma
#     copying numpy/ma/bench.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/ma
#     copying numpy/ma/timer_comparison.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/ma
#     copying numpy/ma/core.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/ma
#     copying numpy/ma/extras.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/ma
#     copying numpy/ma/setup.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/ma
#     copying numpy/ma/testutils.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/ma
#     copying numpy/ma/mrecords.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/ma
#     creating build/lib.linux-x86_64-3.6-pydebug/numpy/ma/tests
#     copying numpy/ma/tests/__init__.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/ma/tests
#     copying numpy/ma/tests/test_old_ma.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/ma/tests
#     copying numpy/ma/tests/test_core.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/ma/tests
#     copying numpy/ma/tests/test_deprecations.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/ma/tests
#     copying numpy/ma/tests/test_regression.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/ma/tests
#     copying numpy/ma/tests/test_extras.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/ma/tests
#     copying numpy/ma/tests/test_mrecords.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/ma/tests
#     copying numpy/ma/tests/test_subclassing.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/ma/tests
#     creating build/lib.linux-x86_64-3.6-pydebug/numpy/matrixlib
#     copying numpy/matrixlib/__init__.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/matrixlib
#     copying numpy/matrixlib/defmatrix.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/matrixlib
#     copying numpy/matrixlib/setup.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/matrixlib
#     creating build/lib.linux-x86_64-3.6-pydebug/numpy/matrixlib/tests
#     copying numpy/matrixlib/tests/__init__.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/matrixlib/tests
#     copying numpy/matrixlib/tests/test_numeric.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/matrixlib/tests
#     copying numpy/matrixlib/tests/test_regression.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/matrixlib/tests
#     copying numpy/matrixlib/tests/test_matrix_linalg.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/matrixlib/tests
#     copying numpy/matrixlib/tests/test_multiarray.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/matrixlib/tests
#     copying numpy/matrixlib/tests/test_defmatrix.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/matrixlib/tests
#     copying numpy/matrixlib/tests/test_masked_matrix.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/matrixlib/tests
#     copying numpy/matrixlib/tests/test_interaction.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/matrixlib/tests
#     creating build/lib.linux-x86_64-3.6-pydebug/numpy/polynomial
#     copying numpy/polynomial/__init__.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/polynomial
#     copying numpy/polynomial/chebyshev.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/polynomial
#     copying numpy/polynomial/hermite.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/polynomial
#     copying numpy/polynomial/laguerre.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/polynomial
#     copying numpy/polynomial/legendre.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/polynomial
#     copying numpy/polynomial/polyutils.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/polynomial
#     copying numpy/polynomial/hermite_e.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/polynomial
#     copying numpy/polynomial/polynomial.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/polynomial
#     copying numpy/polynomial/setup.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/polynomial
#     copying numpy/polynomial/_polybase.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/polynomial
#     creating build/lib.linux-x86_64-3.6-pydebug/numpy/polynomial/tests
#     copying numpy/polynomial/tests/__init__.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/polynomial/tests
#     copying numpy/polynomial/tests/test_polynomial.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/polynomial/tests
#     copying numpy/polynomial/tests/test_chebyshev.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/polynomial/tests
#     copying numpy/polynomial/tests/test_hermite_e.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/polynomial/tests
#     copying numpy/polynomial/tests/test_polyutils.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/polynomial/tests
#     copying numpy/polynomial/tests/test_classes.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/polynomial/tests
#     copying numpy/polynomial/tests/test_hermite.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/polynomial/tests
#     copying numpy/polynomial/tests/test_legendre.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/polynomial/tests
#     copying numpy/polynomial/tests/test_printing.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/polynomial/tests
#     copying numpy/polynomial/tests/test_laguerre.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/polynomial/tests
#     creating build/lib.linux-x86_64-3.6-pydebug/numpy/random
#     copying numpy/random/__init__.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/random
#     copying numpy/random/setup.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/random
#     copying numpy/random/_pickle.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/random
#     creating build/lib.linux-x86_64-3.6-pydebug/numpy/random/tests
#     copying numpy/random/tests/__init__.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/random/tests
#     copying numpy/random/tests/test_direct.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/random/tests
#     copying numpy/random/tests/test_random.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/random/tests
#     copying numpy/random/tests/test_seed_sequence.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/random/tests
#     copying numpy/random/tests/test_regression.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/random/tests
#     copying numpy/random/tests/test_smoke.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/random/tests
#     copying numpy/random/tests/test_generator_mt19937_regressions.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/random/tests
#     copying numpy/random/tests/test_randomstate_regression.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/random/tests
#     copying numpy/random/tests/test_generator_mt19937.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/random/tests
#     copying numpy/random/tests/test_randomstate.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/random/tests
#     copying numpy/random/tests/test_extending.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/random/tests
#     creating build/lib.linux-x86_64-3.6-pydebug/numpy/testing
#     copying numpy/testing/__init__.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/testing
#     copying numpy/testing/utils.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/testing
#     copying numpy/testing/setup.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/testing
#     copying numpy/testing/print_coercion_tables.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/testing
#     creating build/lib.linux-x86_64-3.6-pydebug/numpy/testing/_private
#     copying numpy/testing/_private/__init__.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/testing/_private
#     copying numpy/testing/_private/utils.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/testing/_private
#     copying numpy/testing/_private/decorators.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/testing/_private
#     copying numpy/testing/_private/nosetester.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/testing/_private
#     copying numpy/testing/_private/parameterized.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/testing/_private
#     copying numpy/testing/_private/noseclasses.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/testing/_private
#     creating build/lib.linux-x86_64-3.6-pydebug/numpy/testing/tests
#     copying numpy/testing/tests/__init__.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/testing/tests
#     copying numpy/testing/tests/test_doctesting.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/testing/tests
#     copying numpy/testing/tests/test_decorators.py -> build/lib.linux-x86_64-3.6-pydebug/numpy/testing/tests
# ...
#     extra options: '-std=c99'
#     gcc: build/src.linux-x86_64-3.6/numpy/core/src/umath/_struct_ufunc_tests.c
#     gcc -shared build/temp.linux-x86_64-3.6-pydebug/build/src.linux-x86_64-3.6/numpy/core/src/umath/_struct_ufunc_tests.o -Lbuild/temp.linux-x86_64-3.6-pydebug -o build/lib.linux-x86_64-3.6-pydebug/numpy/core/_struct_ufunc_tests.cpython-36dm-x86_64-linux-gnu.so
#     building 'numpy.core._operand_flag_tests' extension
#     compiling C sources
#     C compiler: gcc -Wno-unused-result -Wsign-compare -g -Og -Wall -fPIC
#
#     compile options: '-DNPY_INTERNAL_BUILD=1 -DHAVE_NPY_CONFIG_H=1 -D_FILE_OFFSET_BITS=64 -D_LARGEFILE_SOURCE=1 -D_LARGEFILE64_SOURCE=1 -Inumpy/core/include -Ibuild/src.linux-x86_64-3.6/numpy/core/include/numpy -Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/local/include/python3.6dm -Ibuild/src.linux-x86_64-3.6/numpy/core/src/common -Ibuild/src.linux-x86_64-3.6/numpy/core/src/npymath -c'
#     extra options: '-std=c99'
#     gcc: build/src.linux-x86_64-3.6/numpy/core/src/umath/_operand_flag_tests.c
#     gcc -shared build/temp.linux-x86_64-3.6-pydebug/build/src.linux-x86_64-3.6/numpy/core/src/umath/_operand_flag_tests.o -Lbuild/temp.linux-x86_64-3.6-pydebug -o build/lib.linux-x86_64-3.6-pydebug/numpy/core/_operand_flag_tests.cpython-36dm-x86_64-linux-gnu.so
#     building 'numpy.fft._pocketfft_internal' extension
#     compiling C sources
#     C compiler: gcc -Wno-unused-result -Wsign-compare -g -Og -Wall -fPIC
#
#     creating build/temp.linux-x86_64-3.6-pydebug/numpy/fft
#     compile options: '-Inumpy/core/include -Ibuild/src.linux-x86_64-3.6/numpy/core/include/numpy -Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/local/include/python3.6dm -Ibuild/src.linux-x86_64-3.6/numpy/core/src/common -Ibuild/src.linux-x86_64-3.6/numpy/core/src/npymath -c'
#     extra options: '-std=c99'
#     gcc: numpy/fft/_pocketfft.c
#     gcc -shared build/temp.linux-x86_64-3.6-pydebug/numpy/fft/_pocketfft.o -Lbuild/temp.linux-x86_64-3.6-pydebug -o build/lib.linux-x86_64-3.6-pydebug/numpy/fft/_pocketfft_internal.cpython-36dm-x86_64-linux-gnu.so
#     building 'numpy.linalg.lapack_lite' extension
#     compiling C sources
#     C compiler: gcc -Wno-unused-result -Wsign-compare -g -Og -Wall -fPIC
#
#     creating build/temp.linux-x86_64-3.6-pydebug/numpy/linalg
#     creating build/temp.linux-x86_64-3.6-pydebug/numpy/linalg/lapack_lite
#     compile options: '-DHAVE_CBLAS -Inumpy/core/include -Ibuild/src.linux-x86_64-3.6/numpy/core/include/numpy -Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/local/include/python3.6dm -Ibuild/src.linux-x86_64-3.6/numpy/core/src/common -Ibuild/src.linux-x86_64-3.6/numpy/core/src/npymath -c'
#     extra options: '-std=c99'
#     gcc: numpy/linalg/lapack_litemodule.c
#     gcc: numpy/linalg/lapack_lite/python_xerbla.c
#     gcc -shared build/temp.linux-x86_64-3.6-pydebug/numpy/linalg/lapack_litemodule.o build/temp.linux-x86_64-3.6-pydebug/numpy/linalg/lapack_lite/python_xerbla.o -L/usr/lib/x86_64-linux-gnu -Lbuild/temp.linux-x86_64-3.6-pydebug -lopenblas -lopenblas -o build/lib.linux-x86_64-3.6-pydebug/numpy/linalg/lapack_lite.cpython-36dm-x86_64-linux-gnu.so
#     building 'numpy.linalg._umath_linalg' extension
#     compiling C sources
#     C compiler: gcc -Wno-unused-result -Wsign-compare -g -Og -Wall -fPIC
#
#     creating build/temp.linux-x86_64-3.6-pydebug/build/src.linux-x86_64-3.6/numpy/linalg
#     compile options: '-DHAVE_CBLAS -Inumpy/core/include -Ibuild/src.linux-x86_64-3.6/numpy/core/include/numpy -Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/local/include/python3.6dm -Ibuild/src.linux-x86_64-3.6/numpy/core/src/common -Ibuild/src.linux-x86_64-3.6/numpy/core/src/npymath -c'
#     extra options: '-std=c99'
#     gcc: build/src.linux-x86_64-3.6/numpy/linalg/umath_linalg.c
#     gcc -shared build/temp.linux-x86_64-3.6-pydebug/build/src.linux-x86_64-3.6/numpy/linalg/umath_linalg.o build/temp.linux-x86_64-3.6-pydebug/numpy/linalg/lapack_lite/python_xerbla.o -L/usr/lib/x86_64-linux-gnu -Lbuild/temp.linux-x86_64-3.6-pydebug -lnpymath -lopenblas -lopenblas -o build/lib.linux-x86_64-3.6-pydebug/numpy/linalg/_umath_linalg.cpython-36dm-x86_64-linux-gnu.so
#     building 'numpy.random._mt19937' extension
#     compiling C sources
#     C compiler: gcc -Wno-unused-result -Wsign-compare -g -Og -Wall -fPIC
#
#     creating build/temp.linux-x86_64-3.6-pydebug/numpy/random/src/mt19937
#     compile options: '-D_FILE_OFFSET_BITS=64 -D_LARGEFILE_SOURCE=1 -D_LARGEFILE64_SOURCE=1 -DNPY_NO_DEPRECATED_API=0 -Inumpy/random -Inumpy/random/src -Inumpy/random/src/mt19937 -Inumpy/core/include -Ibuild/src.linux-x86_64-3.6/numpy/core/include/numpy -Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/local/include/python3.6dm -Ibuild/src.linux-x86_64-3.6/numpy/core/src/common -Ibuild/src.linux-x86_64-3.6/numpy/core/src/npymath -c'
#     extra options: '-U__GNUC_GNU_INLINE__ -std=c99'
#     gcc: numpy/random/_mt19937.c
#     gcc: numpy/random/src/mt19937/mt19937.c
#     gcc: numpy/random/src/mt19937/mt19937-jump.c
#     gcc -shared build/temp.linux-x86_64-3.6-pydebug/numpy/random/_mt19937.o build/temp.linux-x86_64-3.6-pydebug/numpy/random/src/mt19937/mt19937.o build/temp.linux-x86_64-3.6-pydebug/numpy/random/src/mt19937/mt19937-jump.o -Lbuild/temp.linux-x86_64-3.6-pydebug -lnpyrandom -lm -o build/lib.linux-x86_64-3.6-pydebug/numpy/random/_mt19937.cpython-36dm-x86_64-linux-gnu.so
#     building 'numpy.random._philox' extension
#     compiling C sources
#     C compiler: gcc -Wno-unused-result -Wsign-compare -g -Og -Wall -fPIC
#
#     creating build/temp.linux-x86_64-3.6-pydebug/numpy/random/src/philox
#     compile options: '-D_FILE_OFFSET_BITS=64 -D_LARGEFILE_SOURCE=1 -D_LARGEFILE64_SOURCE=1 -DNPY_NO_DEPRECATED_API=0 -Inumpy/random -Inumpy/random/src -Inumpy/random/src/philox -Inumpy/core/include -Ibuild/src.linux-x86_64-3.6/numpy/core/include/numpy -Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/local/include/python3.6dm -Ibuild/src.linux-x86_64-3.6/numpy/core/src/common -Ibuild/src.linux-x86_64-3.6/numpy/core/src/npymath -c'
#     extra options: '-U__GNUC_GNU_INLINE__ -std=c99'
#     gcc: numpy/random/_philox.c
#     gcc: numpy/random/src/philox/philox.c
#     gcc -shared build/temp.linux-x86_64-3.6-pydebug/numpy/random/_philox.o build/temp.linux-x86_64-3.6-pydebug/numpy/random/src/philox/philox.o -Lbuild/temp.linux-x86_64-3.6-pydebug -lnpyrandom -lm -o build/lib.linux-x86_64-3.6-pydebug/numpy/random/_philox.cpython-36dm-x86_64-linux-gnu.so
#     building 'numpy.random._pcg64' extension
#     compiling C sources
#     C compiler: gcc -Wno-unused-result -Wsign-compare -g -Og -Wall -fPIC
#
#     creating build/temp.linux-x86_64-3.6-pydebug/numpy/random/src/pcg64
#     compile options: '-D_FILE_OFFSET_BITS=64 -D_LARGEFILE_SOURCE=1 -D_LARGEFILE64_SOURCE=1 -DNPY_NO_DEPRECATED_API=0 -Inumpy/random -Inumpy/random/src -Inumpy/random/src/pcg64 -Inumpy/core/include -Ibuild/src.linux-x86_64-3.6/numpy/core/include/numpy -Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/local/include/python3.6dm -Ibuild/src.linux-x86_64-3.6/numpy/core/src/common -Ibuild/src.linux-x86_64-3.6/numpy/core/src/npymath -c'
#     extra options: '-U__GNUC_GNU_INLINE__ -std=c99'
#     gcc: numpy/random/_pcg64.c
#     gcc: numpy/random/src/pcg64/pcg64.c
#     gcc -shared build/temp.linux-x86_64-3.6-pydebug/numpy/random/_pcg64.o build/temp.linux-x86_64-3.6-pydebug/numpy/random/src/pcg64/pcg64.o -Lbuild/temp.linux-x86_64-3.6-pydebug -lnpyrandom -lm -o build/lib.linux-x86_64-3.6-pydebug/numpy/random/_pcg64.cpython-36dm-x86_64-linux-gnu.so
#     building 'numpy.random._sfc64' extension
#     compiling C sources
#     C compiler: gcc -Wno-unused-result -Wsign-compare -g -Og -Wall -fPIC
#
#     creating build/temp.linux-x86_64-3.6-pydebug/numpy/random/src/sfc64
#     compile options: '-D_FILE_OFFSET_BITS=64 -D_LARGEFILE_SOURCE=1 -D_LARGEFILE64_SOURCE=1 -DNPY_NO_DEPRECATED_API=0 -Inumpy/random -Inumpy/random/src -Inumpy/random/src/sfc64 -Inumpy/core/include -Ibuild/src.linux-x86_64-3.6/numpy/core/include/numpy -Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/local/include/python3.6dm -Ibuild/src.linux-x86_64-3.6/numpy/core/src/common -Ibuild/src.linux-x86_64-3.6/numpy/core/src/npymath -c'
#     extra options: '-U__GNUC_GNU_INLINE__ -std=c99'
#     gcc: numpy/random/_sfc64.c
#     gcc: numpy/random/src/sfc64/sfc64.c
#     gcc -shared build/temp.linux-x86_64-3.6-pydebug/numpy/random/_sfc64.o build/temp.linux-x86_64-3.6-pydebug/numpy/random/src/sfc64/sfc64.o -Lbuild/temp.linux-x86_64-3.6-pydebug -lnpyrandom -lm -o build/lib.linux-x86_64-3.6-pydebug/numpy/random/_sfc64.cpython-36dm-x86_64-linux-gnu.so
#     building 'numpy.random._common' extension
#     compiling C sources
#     C compiler: gcc -Wno-unused-result -Wsign-compare -g -Og -Wall -fPIC
#
#     compile options: '-D_FILE_OFFSET_BITS=64 -D_LARGEFILE_SOURCE=1 -D_LARGEFILE64_SOURCE=1 -DNPY_NO_DEPRECATED_API=0 -Inumpy/random -Inumpy/random/src -Inumpy/core/include -Ibuild/src.linux-x86_64-3.6/numpy/core/include/numpy -Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/local/include/python3.6dm -Ibuild/src.linux-x86_64-3.6/numpy/core/src/common -Ibuild/src.linux-x86_64-3.6/numpy/core/src/npymath -c'
#     extra options: '-U__GNUC_GNU_INLINE__ -std=c99'
#     gcc: numpy/random/_common.c
#     gcc -shared build/temp.linux-x86_64-3.6-pydebug/numpy/random/_common.o -Lbuild/temp.linux-x86_64-3.6-pydebug -lnpyrandom -lm -o build/lib.linux-x86_64-3.6-pydebug/numpy/random/_common.cpython-36dm-x86_64-linux-gnu.so
#     building 'numpy.random.bit_generator' extension
#     compiling C sources
#     C compiler: gcc -Wno-unused-result -Wsign-compare -g -Og -Wall -fPIC
#
#     compile options: '-D_FILE_OFFSET_BITS=64 -D_LARGEFILE_SOURCE=1 -D_LARGEFILE64_SOURCE=1 -DNPY_NO_DEPRECATED_API=0 -Inumpy/random -Inumpy/random/src -Inumpy/core/include -Ibuild/src.linux-x86_64-3.6/numpy/core/include/numpy -Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/local/include/python3.6dm -Ibuild/src.linux-x86_64-3.6/numpy/core/src/common -Ibuild/src.linux-x86_64-3.6/numpy/core/src/npymath -c'
#     extra options: '-U__GNUC_GNU_INLINE__ -std=c99'
#     gcc: numpy/random/bit_generator.c
#     gcc -shared build/temp.linux-x86_64-3.6-pydebug/numpy/random/bit_generator.o -Lbuild/temp.linux-x86_64-3.6-pydebug -lnpyrandom -lm -o build/lib.linux-x86_64-3.6-pydebug/numpy/random/bit_generator.cpython-36dm-x86_64-linux-gnu.so
#     building 'numpy.random._generator' extension
#     compiling C sources
#     C compiler: gcc -Wno-unused-result -Wsign-compare -g -Og -Wall -fPIC
#
#     compile options: '-D_FILE_OFFSET_BITS=64 -D_LARGEFILE_SOURCE=1 -D_LARGEFILE64_SOURCE=1 -DNPY_NO_DEPRECATED_API=0 -Inumpy/random -Inumpy/random/src -Inumpy/core/include -Ibuild/src.linux-x86_64-3.6/numpy/core/include/numpy -Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/local/include/python3.6dm -Ibuild/src.linux-x86_64-3.6/numpy/core/src/common -Ibuild/src.linux-x86_64-3.6/numpy/core/src/npymath -c'
#     extra options: '-U__GNUC_GNU_INLINE__ -std=c99'
#     gcc: numpy/random/_generator.c
#     gcc -shared build/temp.linux-x86_64-3.6-pydebug/numpy/random/_generator.o -Lbuild/temp.linux-x86_64-3.6-pydebug -lnpyrandom -lm -o build/lib.linux-x86_64-3.6-pydebug/numpy/random/_generator.cpython-36dm-x86_64-linux-gnu.so
#     building 'numpy.random._bounded_integers' extension
#     compiling C sources
#     C compiler: gcc -Wno-unused-result -Wsign-compare -g -Og -Wall -fPIC
#
#     compile options: '-D_FILE_OFFSET_BITS=64 -D_LARGEFILE_SOURCE=1 -D_LARGEFILE64_SOURCE=1 -DNPY_NO_DEPRECATED_API=0 -Inumpy/random -Inumpy/random/src -Inumpy/core/include -Ibuild/src.linux-x86_64-3.6/numpy/core/include/numpy -Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/local/include/python3.6dm -Ibuild/src.linux-x86_64-3.6/numpy/core/src/common -Ibuild/src.linux-x86_64-3.6/numpy/core/src/npymath -c'
#     extra options: '-U__GNUC_GNU_INLINE__ -std=c99'
#     gcc: numpy/random/_bounded_integers.c
#     gcc -shared build/temp.linux-x86_64-3.6-pydebug/numpy/random/_bounded_integers.o -Lbuild/temp.linux-x86_64-3.6-pydebug -lnpyrandom -lm -o build/lib.linux-x86_64-3.6-pydebug/numpy/random/_bounded_integers.cpython-36dm-x86_64-linux-gnu.so
#     building 'numpy.random.mtrand' extension
#     compiling C sources
#     C compiler: gcc -Wno-unused-result -Wsign-compare -g -Og -Wall -fPIC
#
#     creating build/temp.linux-x86_64-3.6-pydebug/numpy/random/src/legacy
#     compile options: '-D_FILE_OFFSET_BITS=64 -D_LARGEFILE_SOURCE=1 -D_LARGEFILE64_SOURCE=1 -DNPY_NO_DEPRECATED_API=0 -DNP_RANDOM_LEGACY=1 -Inumpy/random -Inumpy/random/src -Inumpy/random/src/legacy -Inumpy/core/include -Ibuild/src.linux-x86_64-3.6/numpy/core/include/numpy -Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/local/include/python3.6dm -Ibuild/src.linux-x86_64-3.6/numpy/core/src/common -Ibuild/src.linux-x86_64-3.6/numpy/core/src/npymath -c'
#     extra options: '-U__GNUC_GNU_INLINE__ -std=c99'
#     gcc: numpy/random/mtrand.c
#     gcc: numpy/random/src/legacy/legacy-distributions.c
#     gcc: numpy/random/src/distributions/distributions.c
#     gcc -shared build/temp.linux-x86_64-3.6-pydebug/numpy/random/mtrand.o build/temp.linux-x86_64-3.6-pydebug/numpy/random/src/legacy/legacy-distributions.o build/temp.linux-x86_64-3.6-pydebug/numpy/random/src/distributions/distributions.o -Lbuild/temp.linux-x86_64-3.6-pydebug -lm -o build/lib.linux-x86_64-3.6-pydebug/numpy/random/mtrand.cpython-36dm-x86_64-linux-gnu.so
#     running install_lib
#     creating /usr/local/lib/python3.6/site-packages/numpy
#     error: could not create '/usr/local/lib/python3.6/site-packages/numpy': Permission denied
#
#     ----------------------------------------
# Command "/usr/local/bin/python3.6 -u -c "import setuptools, tokenize;__file__='/tmp/pip-install-l62xwzdo/numpy/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" install --record /tmp/pip-record-dzr19baa/install-record.txt --single-version-externally-managed --compile" failed with error code 1 in /tmp/pip-install-l62xwzdo/numpy/
# You are using pip version 18.1, however version 21.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# from baselines.cetopictm import CETopicTM
from utils import prepare_dataset

dataset, sentences = prepare_dataset('bbc')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1503397/31634005.py in <module>
#       1 # from baselines.cetopictm import CETopicTM
# ----> 2 from utils import prepare_dataset
#       3
#       4 dataset, sentences = prepare_dataset('bbc')
#
# ~/222011815/clone/percobaan/semnas-2024/topicx-main/utils.py in <module>
# ----> 1 from octis.dataset.dataset import Dataset
#       2
#       3 def prepare_dataset(dataset_name):
#       4
#       5     dataset = Dataset()
#
# ModuleNotFoundError: No module named 'octis'
